# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Model 1
#
# The first model has 20 state features and uses a learning rate of 1e-2. The parameters fed to the agent and network are as follows:
#
# ```python
# train_parameters = {
#     'observation_dim': 20,
#     'action_dim': 10,
#     'action_space': list(range(1,11)),
#     'hidden_layer_num': 2,
#     'hidden_layer_dim': 512,
#     'gamma': 0.99,
#
#     'total_training_time_step': 500_00,
#
#     'epsilon_start_value': 1.0,
#     'epsilon_end_value': 0.01,
#     'epsilon_duration': 250_000,
#
#     'replay_buffer_size': 50000,
#     'start_training_step': 1000,
#     'freq_update_behavior_policy': 4,
#     'freq_update_target_policy': 2000,
#
#     'batch_size': 64,
#     'learning_rate': 1e-2,
# }
# ```

# %%
# plot an array as averages of the last 10
def averages_list(arr):
    newArr = np.array(arr)
    for i in range(len(newArr)-1, 10, 9):
        newArr[i] = np.mean(arr[i-10:i])
    return newArr[10:]

# %%
loss_arr = np.load('data/Experiment1/train_loss.npy')
returns_arr = np.load('data/Experiment1/train_returns.npy')

# %%
# plot returns as an average of the last ten
plt.xlabel('Episode')
plt.ylabel('Return')
plt.title('Total return per episode - Model 1')
plt.ylim(-80, 50)
plt.plot(averages_list(returns_arr))

# %%
plt.xlabel('Batch')
plt.ylabel('Loss')
plt.title('Loss for each training iteration - Model 1')
plt.ylim(0, 150)
plt.plot(averages_list(new_arr))

# %% [markdown]
# ## Model 2
#
# The second model has 30 state features and uses a learning rate of 1e-3. It also trains in less timesteps, limited to 375,000 rather than 500,000 for the first model. The parameters fed to the network are as follows:
#
# ```python
# train_parameters = {
#     'observation_dim': 30,
#     'action_dim': 10,
#     'action_space': list(range(1,11)),
#     'hidden_layer_num': 2,
#     'hidden_layer_dim': 512,
#     'gamma': 0.99,
#
#     'total_training_time_step': 350_000,
#
#     'epsilon_start_value': 1.0,
#     'epsilon_end_value': 0.01,
#     'epsilon_duration': 175_000,
#
#     'replay_buffer_size': 50000,
#     'start_training_step': 1000,
#     'freq_update_behavior_policy': 4,
#     'freq_update_target_policy': 2000,
#
#     'batch_size': 64,
#     'learning_rate': 1e-3,
# }
# ```

# %%
loss_arr = np.load('data/Experiment2/train_loss.npy')
returns_arr = np.load('data/Experiment2/train_returns.npy')
turns_arr = np.load('data/Experiment2/turns_taken_per_ep.npy')

# %%
# plot returns as an average of the last ten
plt.xlabel('Episode')
plt.ylabel('Return')
plt.title('Total return per episode - Model 2')
plt.ylim(-80, 50)
plt.plot(averages_list(returns_arr), color='orange')

# %%
plt.xlabel('Batch')
plt.ylabel('Loss')
plt.title('Loss for each training iteration - Model 2')
plt.ylim(0, 150)
plt.plot(averages_list(loss_arr), color='orange')

# %%
plt.xlabel('Episode')
plt.ylabel('Turns')
plt.title('Battle Turns per Episode - Model 2')
plt.ylim(0, 150)
plt.plot(turns_arr, color='orange')

# %% [markdown]
# ## Post-Training Experiments

# %% [markdown]
# This data was collected after the training of the models completed. The results can be replicated by running [`dqn_demo.py`](dqn_demo.py) with all necessary changes made to the parameters of the agent and network.
# (i.e, edit the `TRIAL_MODE` and `MODEL_NUM` variables to your liking)

# %%
# number of wins in 100 trial runs

# experiment 1
wins1 = 77

# experiment 2
wins2 = 100

plt.xlabel('Model')
returns1Losses = [-60.397396047786536, -49.01429775628677, -53.37001544035829, -49.01429775628677, -49.01429775628677, -53.37001544035829, -53.37001544035829, -49.01429775628677, -49.01429775628677, -49.01429775628677, -53.37001544035829, -53.37001544035829, -56.83538051904809, -53.37001544035829, -49.01429775628677, -44.86362407239297, -53.37001544035829, -51.398585376371344, -53.37001544035829, -49.01429775628677, -49.01429775628677, -53.37001544035829, -49.01429775628677]

# experiment 2
returns2 = [17.667346714677773, 21.822706751840055, -15.788412153070269, 39.29518078367411, -8.862399033383046, 17.667346714677773, 32.25199675465901, 39.29518078367411, 39.29518078367411, 21.822706751840055, 32.25199675465901, 32.25199675465901, -26.4604763750758645, 32.25199675465901, 39.29518078367411, 17.667346714677773, 17.667346714677773, -29.316619203475447, 39.29518078367411, 21.822706751840055, 17.667346714677773, 32.25199675465901, 21.822706751840055, 32.25199675465901, 34.008377473617735, 17.667346714677773, 39.29518078367411, 21.822706751840055, 32.25199675465901, -0.7504972842734264, 17.667346714677773, 11.628342580575588, 21.822706751840055, 32.25199675465901, 21.822706751840055, 39.29518078367411, 39.29518078367411, 30.252228239464564, -29.316619203475447, 17.667346714677773, 17.667346714677773, 21.822706751840055, 17.667346714677773, 17.667346714677773, 21.822706751840055, -29.316619203475447, 17.667346714677773, 26.802004498042738, -29.316619203475447, 32.25199675465901, -29.316619203475447, 21.822706751840055, 39.29518078367411, 39.29518078367411, 17.667346714677773, 21.822706751840055, 39.29518078367411, 32.25199675465901, 17.667346714677773, 21.822706751840055, 39.29518078367411, -29.316619203475447, -29.316619203475447, 39.29518078367411, 39.29518078367411, -29.316619203475447, 17.667346714677773, 21.822706751840055, 11.801759451441626, 30.33552137728622, 17.667346714677773, 39.29518078367411, 17.667346714677773, 39.29518078367411, -8.862399033383046, 21.822706751840055, 21.822706751840055, 39.29518078367411, 32.25199675465901, 32.25199675465901, -29.316619203475447, 39.29518078367411, 17.667346714677773, -2.0110780050155093, 17.667346714677773, 32.25199675465901, 32.25199675465901, 41.34164631734094]
returns2Wins = returns2
returns2Losses = []

plt.xlabel('Episode')
plt.ylabel('Return')
plt.title('Total Returns from 100 Battles')
plt.plot(returns1, label=f"Model 1 - mean: {np.mean(returns1)}")
plt.plot(returns2, label=f"Model 2 - mean: {np.mean(returns2)}")
plt.legend(loc='lower center')

# %%
# average returns for wins and losses in trial runs

plt.xlabel('Experiment')
plt.ylabel('Wins')
plt.title('Average Returns per 100')
r = np.arange(3)
plt.bar(r - 0.2, [np.mean(returns1Wins), np.mean(returns1Losses), np.mean(returns1)], width=0.4, edgecolor='black', label="Model 1")
plt.bar(r + 0.2, [np.mean(returns2Wins), np.mean(returns2Losses), np.mean(returns2)], width=0.4, edgecolor='black', label="Model 2")
plt.axhline(color='black', linewidth='0.5')
plt.xticks(r, ["Wins", "Losses", "All"])
plt.legend()
# Out:
# c:\Users\drewi\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\drewi\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
